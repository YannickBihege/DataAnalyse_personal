# %%
import pandas as pd

# %%
df = pd.read_json('supermarkets.json')

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2= pd.read_excel('supermarkets.xlsx', sheet_name= 0)
df3= pd.read_excel('supermarkets.xlsx', sheet_name= 1)

# %%
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3
# Out:
#    ID         Address           City             State Country  \
# 0   1    3666 21st St  San Francisco          CA 94114     USA
# 1   2  735 Dolores St  San Francisco          CA 94119     USA
# 2   3     332 Hill St  San Francisco  California 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25

# %%
df4=pd.read_csv('supermarkets-commas.txt')
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pd.read_csv('supermarkets-semi-colons.txt', sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pd.read_json('http://pythonhow.com/supermarkets.json')

# %%
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = pd.read_csv('data.txt', header= None)
df7
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df7.columns =["ID","Address","City","State","Country","Name","Employees"]
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# df7.set_index("Address", inplace=True)
# df7

# %%
df7.set_index("Address", inplace=True , drop =False)
df7
# Out:
#                  ID          Address           City             State Country  \
# Address
# 3666 21st St      1     3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    2   735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St       3      332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St      4     3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Employees
# Address
# 3666 21st St         Madeira          8
# 735 Dolores St   Bready Shop         15
# 332 Hill St      Super River         25
# 3995 23rd St      Ben's Shop         10
# 1056 Sanchez St      Sanchez         12
# 551 Alvarado St   Richvalley         20

# %%
df7.loc["3666 21st St":"3995 23rd St"]
# Out:
#                 ID         Address           City             State Country  \
# Address
# 3666 21st St     1    3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St   2  735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St      3     332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St     4    3995 23rd St  San Francisco          CA 94114     USA
#
#                        Name  Employees
# Address
# 3666 21st St        Madeira          8
# 735 Dolores St  Bready Shop         15
# 332 Hill St     Super River         25
# 3995 23rd St     Ben's Shop         10

# %%
df7.iloc[1:3,1:3]
# Out:
#                        Address           City
# Address
# 735 Dolores St  735 Dolores St  San Francisco
# 332 Hill St        332 Hill St  San Francisco

# %%
df7.shape[0]*["North America"]
# Out:
# ['North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America']

# %%
df7["continent"] =df7.shape[0]*["North America"]

# %%
df7
# Out:
#                  ID          Address           City             State Country  \
# Address
# 3666 21st St      1     3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    2   735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St       3      332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St      4     3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Employees      continent
# Address
# 3666 21st St         Madeira          8  North America
# 735 Dolores St   Bready Shop         15  North America
# 332 Hill St      Super River         25  North America
# 3995 23rd St      Ben's Shop         10  North America
# 1056 Sanchez St      Sanchez         12  North America
# 551 Alvarado St   Richvalley         20  North America

# %%
df7["Location"] = df7["continent"]+ ", USA"

# %%
df7
# Out:
#                  ID          Address           City             State Country  \
# Address
# 3666 21st St      1     3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    2   735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St       3      332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St      4     3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St   5  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Employees      continent            Location
# Address
# 3666 21st St         Madeira          8  North America  North America, USA
# 735 Dolores St   Bready Shop         15  North America  North America, USA
# 332 Hill St      Super River         25  North America  North America, USA
# 3995 23rd St      Ben's Shop         10  North America  North America, USA
# ...

# %%
#from geopy.geocoders import ArcGis
pip  install geopy
# Out:
#   File "<ipython-input-26-47c1f223c28b>", line 2
#     anconda  install geopy
#                    ^
# SyntaxError: invalid syntax

# %%
nom = ArcGis()
