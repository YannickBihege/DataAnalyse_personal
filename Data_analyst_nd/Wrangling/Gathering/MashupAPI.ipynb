# %%
import pandas as pd
import requests
import os
import glob
import pandas as pd
import numpy as np
import wptools
import json
from PIL import Image
from io import BytesIO

# %%
title_list = [
 'The_Wizard_of_Oz_(1939_film)',
 'Citizen_Kane',
 'The_Third_Man',
 'Get_Out_(film)',
 'Mad_Max:_Fury_Road',
 'The_Cabinet_of_Dr._Caligari',
 'All_About_Eve',
 'Inside_Out_(2015_film)',
 'The_Godfather',
 'Metropolis_(1927_film)',
 'E.T._the_Extra-Terrestrial',
 'Modern_Times_(film)',
 'It_Happened_One_Night',
 "Singin'_in_the_Rain",
 'Boyhood_(film)',
 'Casablanca_(film)',
 'Moonlight_(2016_film)',
 'Psycho_(1960_film)',
 'Laura_(1944_film)',
 'Nosferatu',
 'Snow_White_and_the_Seven_Dwarfs_(1937_film)',
 "A_Hard_Day%27s_Night_(film)",
 'La_Grande_Illusion',
 'North_by_Northwest',
 'The_Battle_of_Algiers',
 'Dunkirk_(2017_film)',
 'The_Maltese_Falcon_(1941_film)',
 'Repulsion_(film)',
 '12_Years_a_Slave_(film)',
 'Gravity_(2013_film)',
 'Sunset_Boulevard_(film)',
 'King_Kong_(1933_film)',
 'Spotlight_(film)',
 'The_Adventures_of_Robin_Hood',
 'Rashomon',
 'Rear_Window',
 'Selma_(film)',
 'Taxi_Driver',
 'Toy_Story_3',
 'Argo_(2012_film)',
 'Toy_Story_2',
 'The_Big_Sick',
 'Bride_of_Frankenstein',
 'Zootopia',
 'M_(1931_film)',
 'Wonder_Woman_(2017_film)',
 'The_Philadelphia_Story_(film)',
 'Alien_(film)',
 'Bicycle_Thieves',
 'Seven_Samurai',
 'The_Treasure_of_the_Sierra_Madre_(film)',
 'Up_(2009_film)',
 '12_Angry_Men_(1957_film)',
 'The_400_Blows',
 'Logan_(film)',
 'All_Quiet_on_the_Western_Front_(1930_film)',
 'Army_of_Shadows',
 'Arrival_(film)',
 'Baby_Driver',
 'A_Streetcar_Named_Desire_(1951_film)',
 'The_Night_of_the_Hunter_(film)',
 'Star_Wars:_The_Force_Awakens',
 'Manchester_by_the_Sea_(film)',
 'Dr._Strangelove',
 'Frankenstein_(1931_film)',
 'Vertigo_(film)',
 'The_Dark_Knight_(film)',
 'Touch_of_Evil',
 'The_Babadook',
 'The_Conformist_(film)',
 'Rebecca_(1940_film)',
 "Rosemary%27s_Baby_(film)",
 'Finding_Nemo',
 'Brooklyn_(film)',
 'The_Wrestler_(2008_film)',
 'The_39_Steps_(1935_film)',
 'L.A._Confidential_(film)',
 'Gone_with_the_Wind_(film)',
 'The_Good,_the_Bad_and_the_Ugly',
 'Skyfall',
 'Rome,_Open_City',
 'Tokyo_Story',
 'Hell_or_High_Water_(film)',
 'Pinocchio_(1940_film)',
 'The_Jungle_Book_(2016_film)',
 'La_La_Land_(film)',
 'Star_Trek_(film)',
 'High_Noon',
 'Apocalypse_Now',
 'On_the_Waterfront',
 'The_Wages_of_Fear',
 'The_Last_Picture_Show',
 'Harry_Potter_and_the_Deathly_Hallows_–_Part_2',
 'The_Grapes_of_Wrath_(film)',
 'Roman_Holiday',
 'Man_on_Wire',
 'Jaws_(film)',
 'Toy_Story',
 'The_Godfather_Part_II',
 'Battleship_Potemkin'
]

# %%
#create an empty folder
folder_name = 'bestofrt_posters'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
# List of dictionaries to build and convert to a DataFrame later
df_list = []
image_errors = {}
for title in title_list:
    try:
        # This cell is slow so print ranking to gauge time remaining
        ranking = title_list.index(title) + 1
        print(ranking)
        page = wptools.page(title, silent=True)
        # Your code here (three lines)
        images = page.get().data['image']
        # First image is usually the poster
        first_image_url = images[0]['url']
        r = requests.get(url)
        # Download movie poster image
        i = Image.open(BytesIO(r.content))
        image_file_format = first_image_url.split('.')[-1]
        i.save(folder_name + "/" + str(ranking) + "_" + title + '.' + image_file_format)
        # Append to list of dictionaries
        df_list.append({'ranking': int(ranking),
                        'title': title,
                        'poster_url': first_image_url})
    
    # Not best practice to catch all exceptions but fine for this short script
    except Exception as e:
        print(str(ranking) + "_" + title + ": " + str(e))
        image_errors[str(ranking) + "_" + title] = images
# Out:
# 1
# 1_The_Wizard_of_Oz_(1939_film): name 'url' is not defined
# 2
# 2_Citizen_Kane: name 'url' is not defined
# 3
# 3_The_Third_Man: name 'url' is not defined
# 4
# 4_Get_Out_(film): name 'url' is not defined
# 5
# 5_Mad_Max:_Fury_Road: name 'url' is not defined
# 6
# 6_The_Cabinet_of_Dr._Caligari: name 'url' is not defined
# 7
# 7_All_About_Eve: name 'url' is not defined
# 8
# 8_Inside_Out_(2015_film): name 'url' is not defined
# 9
# 9_The_Godfather: name 'url' is not defined
# 10
# 10_Metropolis_(1927_film): name 'url' is not defined
# 11
# 11_E.T._the_Extra-Terrestrial: name 'url' is not defined
# 12
# 12_Modern_Times_(film): name 'url' is not defined
# 13
# 13_It_Happened_One_Night: name 'url' is not defined
# 14
# 14_Singin'_in_the_Rain: name 'url' is not defined
# 15
# 15_Boyhood_(film): name 'url' is not defined
# 16
# 16_Casablanca_(film): name 'url' is not defined
# 17
# 17_Moonlight_(2016_film): name 'url' is not defined
# 18
# 18_Psycho_(1960_film): name 'url' is not defined
# 19
# 19_Laura_(1944_film): name 'url' is not defined
# 20
# 20_Nosferatu: name 'url' is not defined
# 21
# 21_Snow_White_and_the_Seven_Dwarfs_(1937_film): name 'url' is not defined
# 22
# API error: {'code': 'invalidtitle', 'info': 'Bad title "A_Hard_Day%27s_Night_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# 22_A_Hard_Day%27s_Night_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=A_Hard_Day%2527s_Night_%28film%29
# 23
# 23_La_Grande_Illusion: name 'url' is not defined
# 24
# 24_North_by_Northwest: name 'url' is not defined
# 25
# 25_The_Battle_of_Algiers: name 'url' is not defined
# 26
# 26_Dunkirk_(2017_film): name 'url' is not defined
# 27
# 27_The_Maltese_Falcon_(1941_film): name 'url' is not defined
# 28
# 28_Repulsion_(film): name 'url' is not defined
# 29
# 29_12_Years_a_Slave_(film): name 'url' is not defined
# 30
# 30_Gravity_(2013_film): name 'url' is not defined
# 31
# 31_Sunset_Boulevard_(film): name 'url' is not defined
# 32
# 32_King_Kong_(1933_film): name 'url' is not defined
# 33
# 33_Spotlight_(film): name 'url' is not defined
# 34
# 34_The_Adventures_of_Robin_Hood: name 'url' is not defined
# 35
# 35_Rashomon: name 'url' is not defined
# 36
# 36_Rear_Window: name 'url' is not defined
# 37
# 37_Selma_(film): name 'url' is not defined
# 38
# 38_Taxi_Driver: name 'url' is not defined
# 39
# 39_Toy_Story_3: name 'url' is not defined
# 40
# 40_Argo_(2012_film): name 'url' is not defined
# 41
# 41_Toy_Story_2: name 'url' is not defined
# 42
# 42_The_Big_Sick: name 'url' is not defined
# 43
# 43_Bride_of_Frankenstein: name 'url' is not defined
# 44
# 44_Zootopia: name 'url' is not defined
# 45
# 45_M_(1931_film): name 'url' is not defined
# 46
# 46_Wonder_Woman_(2017_film): name 'url' is not defined
# 47
# 47_The_Philadelphia_Story_(film): name 'url' is not defined
# 48
# 48_Alien_(film): name 'url' is not defined
# 49
# 49_Bicycle_Thieves: name 'url' is not defined
# 50
# 50_Seven_Samurai: name 'url' is not defined
# 51
# 51_The_Treasure_of_the_Sierra_Madre_(film): name 'url' is not defined
# 52
# 52_Up_(2009_film): name 'url' is not defined
# 53
# 53_12_Angry_Men_(1957_film): name 'url' is not defined
# 54
# 54_The_400_Blows: name 'url' is not defined
# 55
# 55_Logan_(film): name 'url' is not defined
# 56
# 56_All_Quiet_on_the_Western_Front_(1930_film): name 'url' is not defined
# 57
# 57_Army_of_Shadows: name 'url' is not defined
# 58
# 58_Arrival_(film): name 'url' is not defined
# 59
# 59_Baby_Driver: name 'url' is not defined
# 60
# 60_A_Streetcar_Named_Desire_(1951_film): name 'url' is not defined
# 61
# 61_The_Night_of_the_Hunter_(film): name 'url' is not defined
# 62
# 62_Star_Wars:_The_Force_Awakens: name 'url' is not defined
# 63
# 63_Manchester_by_the_Sea_(film): name 'url' is not defined
# 64
# 64_Dr._Strangelove: name 'url' is not defined
# 65
# 65_Frankenstein_(1931_film): name 'url' is not defined
# 66
# 66_Vertigo_(film): name 'url' is not defined
# 67
# 67_The_Dark_Knight_(film): name 'url' is not defined
# 68
# 68_Touch_of_Evil: name 'url' is not defined
# 69
# 69_The_Babadook: name 'url' is not defined
# 70
# 70_The_Conformist_(film): name 'url' is not defined
# 71
# 71_Rebecca_(1940_film): name 'url' is not defined
# 72
# API error: {'code': 'invalidtitle', 'info': 'Bad title "Rosemary%27s_Baby_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# 72_Rosemary%27s_Baby_(film): https://en.wikipedia.org/w/api.php?action=parse&formatversion=2&contentmodel=text&disableeditsection=&disablelimitreport=&disabletoc=&prop=text|iwlinks|parsetree|wikitext|displaytitle|properties&redirects&page=Rosemary%2527s_Baby_%28film%29
# 73
# 73_Finding_Nemo: name 'url' is not defined
# 74
# 74_Brooklyn_(film): name 'url' is not defined
# 75
# 75_The_Wrestler_(2008_film): name 'url' is not defined
# 76
# 76_The_39_Steps_(1935_film): name 'url' is not defined
# 77
# 77_L.A._Confidential_(film): name 'url' is not defined
# 78
# 78_Gone_with_the_Wind_(film): name 'url' is not defined
# 79
# 79_The_Good,_the_Bad_and_the_Ugly: name 'url' is not defined
# 80
# 80_Skyfall: name 'url' is not defined
# 81
# 81_Rome,_Open_City: name 'url' is not defined
# 82
# 82_Tokyo_Story: name 'url' is not defined
# 83
# 83_Hell_or_High_Water_(film): 'image'
# 84
# 84_Pinocchio_(1940_film): name 'url' is not defined
# 85
# 85_The_Jungle_Book_(2016_film): name 'url' is not defined
# 86
# 86_La_La_Land_(film): name 'url' is not defined
# 87
# 87_Star_Trek_(film): name 'url' is not defined
# 88
# 88_High_Noon: name 'url' is not defined
# 89
# 89_Apocalypse_Now: name 'url' is not defined
# 90
# 90_On_the_Waterfront: name 'url' is not defined
# 91
# 91_The_Wages_of_Fear: name 'url' is not defined
# 92
# 92_The_Last_Picture_Show: name 'url' is not defined
# 93
# 93_Harry_Potter_and_the_Deathly_Hallows_–_Part_2: name 'url' is not defined
# 94
# 94_The_Grapes_of_Wrath_(film): name 'url' is not defined
# 95
# 95_Roman_Holiday: name 'url' is not defined
# 96
# 96_Man_on_Wire: name 'url' is not defined
# 97
# 97_Jaws_(film): name 'url' is not defined
# 98
# 98_Toy_Story: name 'url' is not defined
# 99
# 99_The_Godfather_Part_II: name 'url' is not defined
# 100
# 100_Battleship_Potemkin: name 'url' is not defined

# %%
for key in image_errors.keys():
    print(key)
# Out:
# 1_The_Wizard_of_Oz_(1939_film)
# 2_Citizen_Kane
# 3_The_Third_Man
# 4_Get_Out_(film)
# 5_Mad_Max:_Fury_Road
# 6_The_Cabinet_of_Dr._Caligari
# 7_All_About_Eve
# 8_Inside_Out_(2015_film)
# 9_The_Godfather
# 10_Metropolis_(1927_film)
# 11_E.T._the_Extra-Terrestrial
# 12_Modern_Times_(film)
# 13_It_Happened_One_Night
# 14_Singin'_in_the_Rain
# 15_Boyhood_(film)
# 16_Casablanca_(film)
# 17_Moonlight_(2016_film)
# 18_Psycho_(1960_film)
# 19_Laura_(1944_film)
# 20_Nosferatu
# 21_Snow_White_and_the_Seven_Dwarfs_(1937_film)
# 22_A_Hard_Day%27s_Night_(film)
# 23_La_Grande_Illusion
# 24_North_by_Northwest
# 25_The_Battle_of_Algiers
# 26_Dunkirk_(2017_film)
# 27_The_Maltese_Falcon_(1941_film)
# 28_Repulsion_(film)
# 29_12_Years_a_Slave_(film)
# 30_Gravity_(2013_film)
# 31_Sunset_Boulevard_(film)
# 32_King_Kong_(1933_film)
# 33_Spotlight_(film)
# 34_The_Adventures_of_Robin_Hood
# 35_Rashomon
# 36_Rear_Window
# 37_Selma_(film)
# 38_Taxi_Driver
# 39_Toy_Story_3
# 40_Argo_(2012_film)
# 41_Toy_Story_2
# 42_The_Big_Sick
# 43_Bride_of_Frankenstein
# 44_Zootopia
# 45_M_(1931_film)
# 46_Wonder_Woman_(2017_film)
# 47_The_Philadelphia_Story_(film)
# 48_Alien_(film)
# 49_Bicycle_Thieves
# 50_Seven_Samurai
# 51_The_Treasure_of_the_Sierra_Madre_(film)
# 52_Up_(2009_film)
# 53_12_Angry_Men_(1957_film)
# 54_The_400_Blows
# 55_Logan_(film)
# 56_All_Quiet_on_the_Western_Front_(1930_film)
# 57_Army_of_Shadows
# 58_Arrival_(film)
# 59_Baby_Driver
# 60_A_Streetcar_Named_Desire_(1951_film)
# 61_The_Night_of_the_Hunter_(film)
# 62_Star_Wars:_The_Force_Awakens
# 63_Manchester_by_the_Sea_(film)
# 64_Dr._Strangelove
# 65_Frankenstein_(1931_film)
# 66_Vertigo_(film)
# 67_The_Dark_Knight_(film)
# 68_Touch_of_Evil
# 69_The_Babadook
# 70_The_Conformist_(film)
# 71_Rebecca_(1940_film)
# 72_Rosemary%27s_Baby_(film)
# 73_Finding_Nemo
# 74_Brooklyn_(film)
# 75_The_Wrestler_(2008_film)
# 76_The_39_Steps_(1935_film)
# 77_L.A._Confidential_(film)
# 78_Gone_with_the_Wind_(film)
# 79_The_Good,_the_Bad_and_the_Ugly
# 80_Skyfall
# 81_Rome,_Open_City
# 82_Tokyo_Story
# 83_Hell_or_High_Water_(film)
# 84_Pinocchio_(1940_film)
# 85_The_Jungle_Book_(2016_film)
# 86_La_La_Land_(film)
# 87_Star_Trek_(film)
# 88_High_Noon
# 89_Apocalypse_Now
# 90_On_the_Waterfront
# 91_The_Wages_of_Fear
# 92_The_Last_Picture_Show
# 93_Harry_Potter_and_the_Deathly_Hallows_–_Part_2
# 94_The_Grapes_of_Wrath_(film)
# 95_Roman_Holiday
# 96_Man_on_Wire
# 97_Jaws_(film)
# 98_Toy_Story
# 99_The_Godfather_Part_II
# 100_Battleship_Potemkin

# %%
# Inspect unidentifiable images and download them individually
for rank_title, images in image_errors.items():
    if rank_title == '22_A_Hard_Day%27s_Night_(film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/4/47/A_Hard_Days_night_movieposter.jpg'
    if rank_title == '53_12_Angry_Men_(1957_film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg'
    if rank_title == '72_Rosemary%27s_Baby_(film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/e/ef/Rosemarys_baby_poster.jpg'
    if rank_title == '93_Harry_Potter_and_the_Deathly_Hallows_–_Part_2':
        url = 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg'
    title = rank_title[3:]
    df_list.append({'ranking': int(title_list.index(title) + 1),
                    'title': title,
                    'poster_url': url})
    r = requests.get(url)
    # Download movie poster image
    i = Image.open(BytesIO(r.content))
    image_file_format = url.split('.')[-1]
    i.save(folder_name + "/" + rank_title + '.' + image_file_format)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-21400a637b79> in <module>
#      10         url = 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg'
#      11     title = rank_title[3:]
# ---> 12     df_list.append({'ranking': int(title_list.index(title) + 1),
#      13                     'title': title,
#      14                     'poster_url': url})
#
# ValueError: 'he_Wizard_of_Oz_(1939_film)' is not in list

# %%
# Create DataFrame from list of dictionaries
df = pd.DataFrame(df_list, columns = ['ranking', 'title', 'poster_url'])
df = df.sort_values('ranking').reset_index(drop=True)
df

# %%
df.to_csv('dataset.csv', index=False)
